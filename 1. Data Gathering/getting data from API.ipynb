# %% [markdown]
# # What is API?
# An API (Application Programming Interface) is a set of rules and tools
# that allows different software applications to communicate and interact with each other,
# enabling seamless access to functionalities and data.
#
#
# simply,An API is like a messenger that lets different apps
# or systems  talk to each other. It defines how they can
# send requests and share information, helping them work together and exchange data.

# %%
import pandas as pd
import requests

# %% [markdown]
# steps:
#     1)get API key
#     2)paste in chrome, you will get JSON(used to fetch data). but not understable
#     3)use tools like ison viewer to understand data (just to understand, not required to fetch data)

# %%
#use request library and call get function, paste url link there. (i,e. key)
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg',
#    'genre_ids': [18, 80],
#    'id': 238,
#    'original_language': 'en',
#    'original_title': 'The Godfather',
#    'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#    'popularity': 142.126,
#    'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#    'release_date': '1972-03-14',
#    'title': 'The Godfather',
#    'video': False,
#    'vote_average': 8.708,
#    'vote_count': 19197},
#   {'adult': False,
#    'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
# ...

# %% [markdown]
# from above we understand that there are total of 452 pages, we are also interested in only values which are stored in dictionary with key results

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
#   'original_title': 'The Godfather',
#   'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#   'popularity': 142.126,
#   'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#   'release_date': '1972-03-14',
#   'title': 'The Godfather',
#   'video': False,
#   'vote_average': 8.708,
#   'vote_count': 19197},
#  {'adult': False,
#   'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
# ...

# %%
#select only those which you are interested , doing for page 1
df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df.head()
# Out:
#       id                        title  \
# 0    238                The Godfather
# 1    278     The Shawshank Redemption
# 2    240        The Godfather Part II
# 3    424             Schindler's List
# 4  19404  Dilwale Dulhania Le Jayenge
#
#                                             overview release_date  popularity  \
# 0  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     142.126
# 1  Framed in the 1940s for the double murder of h...   1994-09-23     114.170
# 2  In the continuing saga of the Corleone crime f...   1974-12-20      65.237
# 3  The true story of how businessman Oskar Schind...   1993-12-15      73.143
# 4  Raj is a rich, carefree, happy-go-lucky second...   1995-10-20      39.680
#
#    vote_average  vote_count
# 0         8.708       19197
# 1         8.700       25186
# 2         8.589       11571
# 3         8.574       14924
# 4         8.548        4305

# %%
df.shape
# Out:
# (20, 7)

# %%
#create empty data frame
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
'''
for i in range(1,453):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = df.append(temp_df,ignore_index=True)
'''
'''
.append is deprecated . so, using concat'''
# Out:
# '\n.append is deprecated . so, using concat'

# %%
import requests
import pandas as pd

# Initialize an empty DataFrame
df = pd.DataFrame()

for i in range(1, 453):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = pd.concat([df, temp_df], ignore_index=True)  #for concatenation of temp_df with df

# %%
df
# Out:
#          id                        title  \
# 0       238                The Godfather
# 1       278     The Shawshank Redemption
# 2       240        The Godfather Part II
# 3       424             Schindler's List
# 4     19404  Dilwale Dulhania Le Jayenge
# ...     ...                          ...
# 9034  13805               Disaster Movie
# 9035   5491            Battlefield Earth
# 9036  11059            House of the Dead
# 9037  14164         Dragonball Evolution
# 9038  40016   Birdemic: Shock and Terror
#
#                                                overview release_date  \
# 0     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 1     Framed in the 1940s for the double murder of h...   1994-09-23
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     Raj is a rich, carefree, happy-go-lucky second...   1995-10-20
# ...

# %%
df.shape
# Out:
# (9039, 7)

# %%
df.to_csv('movies.csv')

# %%
df
# Out:
#          id                        title  \
# 0       238                The Godfather
# 1       278     The Shawshank Redemption
# 2       240        The Godfather Part II
# 3       424             Schindler's List
# 4     19404  Dilwale Dulhania Le Jayenge
# ...     ...                          ...
# 9034  13805               Disaster Movie
# 9035   5491            Battlefield Earth
# 9036  11059            House of the Dead
# 9037  14164         Dragonball Evolution
# 9038  40016   Birdemic: Shock and Terror
#
#                                                overview release_date  \
# 0     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 1     Framed in the 1940s for the double murder of h...   1994-09-23
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     Raj is a rich, carefree, happy-go-lucky second...   1995-10-20
# ...
